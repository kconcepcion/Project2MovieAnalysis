# %%
#import dependancies
from sqlalchemy import create_engine
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# <h3>Extract our CSV's into the DataFrame and Transform it</h3>

# %%
# extract our kaggle movie data
movies1 = "movies1.csv"
movies1_df = pd.read_csv(movies1)
movies1_df.head()
# Out:
#    Unnamed: 0  popularity release_date                        title  \
# 0           6     105.354    8/12/2022  Gabriel's Rapture: Part III
# 1          11    1506.480    7/29/2022                Purple Hearts
# 2          16    1590.428   12/15/2021      Spider-Man: No Way Home
# 3          37     848.034   11/24/2021                      Encanto
# 4          42     176.033     3/4/2022                  Tyson's Run
#
#                                             overview  vote_average  \
# 0  In the sixth installment of the Gabriel's Infe...           8.8
# 1  An aspiring musician agrees to a marriage of c...           8.6
# 2  Peter Parker is unmasked and no longer able to...           8.0
# 3  The tale of an extraordinary family, the Madri...           7.7
# 4  When fifteen-year-old Tyson attends public sch...           8.4
#
#    vote_count original_language               original_title release_month  \
# 0          18                en  Gabriel's Rapture: Part III        August
# 1        1026                en                Purple Hearts          July
# 2       14626                en      Spider-Man: No Way Home      December
# 3        7122                en                      Encanto      November
# 4          38                en                  Tyson's Run         March
#
#    release_year
# 0        2022.0
# 1        2022.0
# 2        2021.0
# 3        2021.0
# 4        2022.0

# %%
# Selecting only the columns that will be relevent to our inquiry
movies1_df = movies1_df[['title', 'popularity', 'vote_average', 'release_month', 'release_year']].copy()
movies1_df.head()
# Out:
#                          title  popularity  vote_average release_month  \
# 0  Gabriel's Rapture: Part III     105.354           8.8        August
# 1                Purple Hearts    1506.480           8.6          July
# 2      Spider-Man: No Way Home    1590.428           8.0      December
# 3                      Encanto     848.034           7.7      November
# 4                  Tyson's Run     176.033           8.4         March
#
#    release_year
# 0        2022.0
# 1        2022.0
# 2        2021.0
# 3        2021.0
# 4        2022.0

# %%
# run to verify data types
movies1_df.dtypes
# Out:
# title             object
# popularity       float64
# vote_average     float64
# release_month     object
# release_year     float64
# dtype: object

# %%
# change release year to an INT data type
movies1_df['release_year'] = movies1_df['release_year'].astype(int)

# %%
movies1_df.dtypes
# Out:
# title             object
# popularity       float64
# vote_average     float64
# release_month     object
# release_year       int32
# dtype: object

# %%
movies1_df
# Out:
#                            title  popularity  vote_average release_month  \
# 0    Gabriel's Rapture: Part III     105.354           8.8        August
# 1                  Purple Hearts    1506.480           8.6          July
# 2        Spider-Man: No Way Home    1590.428           8.0      December
# 3                        Encanto     848.034           7.7      November
# 4                    Tyson's Run     176.033           8.4         March
# ..                           ...         ...           ...           ...
# 515                      WarHunt     889.462           5.2       January
# 516      Gatlopp: Hell of a Game     154.374           5.2          June
# 517                       Brazen     177.901           4.9       January
# 518                  The Hunting     179.192           4.8       January
# 519                   The Requin     363.318           4.6       January
#
#      release_year
# 0            2022
# 1            2022
# 2            2021
# 3            2021
# 4            2022
# ..            ...
# 515          2022
# 516          2022
# 517          2022
# 518          2022
# 519          2022
#
# [520 rows x 5 columns]

# %%
# only include movies released in 2022 to match our movies2 data
movies1_df.drop(movies1_df[movies1_df['release_year'] != 2021].index, inplace = True)
movies1_df.head()
# Out:
#                           title  popularity  vote_average release_month  \
# 2       Spider-Man: No Way Home    1590.428           8.0      December
# 3                       Encanto     848.034           7.7      November
# 5                        Sing 2     641.864           8.0      December
# 10  Venom: Let There Be Carnage     507.932           7.0     September
# 12           The Desperate Hour     501.535           6.2     September
#
#     release_year
# 2           2021
# 3           2021
# 5           2021
# 10          2021
# 12          2021

# %%
# check the number of movies in 2022
len(movies1_df)
# Out:
# 113

# %%
# extract our webscraped movie data
movies2 = "movies2.csv"
movies2_df = pd.read_csv(movies2)
movies2_df.head()
# Out:
#    rank                                      title  \
# 0     1                    Spider-Man: No Way Home
# 1     2  Shang-Chi and the Legend of the Ten Rings
# 2     3                Venom: Let There Be Carnage
# 3     4                                Black Widow
# 4     5                          F9: The Fast Saga
#
#                                 studio release  index         gross
# 0    Sony Pictures Entertainment (SPE)  Dec 17      0  $572,984,769
# 1  Walt Disney Studios Motion Pictures   Sep 3      2  $224,543,292
# 2    Sony Pictures Entertainment (SPE)   Oct 1      4  $212,609,036
# 3  Walt Disney Studios Motion Pictures   Jul 9      6  $183,651,655
# 4                   Universal Pictures  Jun 25      8  $173,005,945

# %%
# Select only the columns that will be relevent to our inquiry
movies2_df = movies2_df[[ 'rank', 'title', 'studio', 'release', 'gross']].copy()
movies2_df.head()
# Out:
#    rank                                      title  \
# 0     1                    Spider-Man: No Way Home
# 1     2  Shang-Chi and the Legend of the Ten Rings
# 2     3                Venom: Let There Be Carnage
# 3     4                                Black Widow
# 4     5                          F9: The Fast Saga
#
#                                 studio release         gross
# 0    Sony Pictures Entertainment (SPE)  Dec 17  $572,984,769
# 1  Walt Disney Studios Motion Pictures   Sep 3  $224,543,292
# 2    Sony Pictures Entertainment (SPE)   Oct 1  $212,609,036
# 3  Walt Disney Studios Motion Pictures   Jul 9  $183,651,655
# 4                   Universal Pictures  Jun 25  $173,005,945

# %%
# check the number of titles in dataset 2
len(movies2_df)
# Out:
# 200

# %%
# Verify the data types of movies2
movies2_df.dtypes
# Out:
# rank        int64
# title      object
# studio     object
# release    object
# gross      object
# dtype: object

# %%
 movie_total = pd.merge(movies1_df,movies2_df, on= ["title"])

# %%
len(movie_total)
# Out:
# 46

# %%
movie_total.head(46)
# Out:
#                                         title  popularity  vote_average  \
# 0                     Spider-Man: No Way Home    1590.428           8.0
# 1                                     Encanto     848.034           7.7
# 2                                      Sing 2     641.864           8.0
# 3                 Venom: Let There Be Carnage     507.932           7.0
# 4   Shang-Chi and the Legend of the Ten Rings     449.042           7.7
# 5                                     Cruella     456.400           8.1
# 6                               After We Fell     409.775           7.2
# 7                                    Eternals     406.522           7.1
# 8      Resident Evil: Welcome to Raccoon City     389.165           6.1
# 9                               Mortal Kombat     364.650           7.2
# 10                    Ghostbusters: Afterlife     323.840           7.6
# 11                   Clifford the Big Red Dog     339.895           7.3
# 12                      PAW Patrol: The Movie     359.695           7.4
# 13     The Conjuring: The Devil Made Me Do It     337.214           7.6
# 14                             The King's Man     302.233           6.9
# 15                          The Suicide Squad     296.762           7.6
# 16                   The Matrix Resurrections     299.084           6.7
# 17                                   Free Guy     264.499           7.7
# 18                        The Addams Family 2     330.782           7.1
# 19                    Space Jam: A New Legacy     248.526           7.0
# 20                              Jungle Cruise     225.971           7.5
# 21                          Godzilla vs. Kong     246.162           7.8
# 22                                Black Widow     267.228           7.4
# 23                                       Dune     248.417           7.9
# 24                                 The Unholy     251.372           6.7
# 25                           Ron's Gone Wrong     226.533           8.1
# 26                   Raya and the Last Dragon     231.215           8.0
# 27                               Wrath of Man     211.614           7.7
# 28                             No Time to Die     188.454           7.5
# 29                      A Quiet Place Part II     203.421           7.6
# 30                          The Forever Purge     207.559           7.2
# 31                            Don't Breathe 2     190.050           7.3
# 32                                Tom & Jerry     183.338           7.0
# 33                            Halloween Kills     195.025           6.7
# 34                                        Old     184.873           6.5
# 35                                     Nobody     182.530           8.1
# 36                            Nightmare Alley     170.388           7.0
# 37                                    Antlers     156.008           6.3
# 38                             Spirit Untamed     151.418           7.4
# 39                              The Last Duel     133.126           7.5
# 40                               The Marksman     123.440           6.9
# 41                                 Separation     125.180           5.8
# 42                                 Wrong Turn     112.344           6.0
# 43                Peter Rabbit 2: The Runaway     112.615           7.2
# 44                                  Malignant     110.535           6.9
# 45       Escape Room: Tournament of Champions      95.969           6.7
#
#    release_month  release_year  rank                               studio  \
# 0       December          2021     1    Sony Pictures Entertainment (SPE)
# 1       November          2021    15  Walt Disney Studios Motion Pictures
# 2       December          2021    17                   Universal Pictures
# 3      September          2021     3    Sony Pictures Entertainment (SPE)
# 4      September          2021     2  Walt Disney Studios Motion Pictures
# 5            May          2021    16  Walt Disney Studios Motion Pictures
# 6      September          2021   106               Vertical Entertainment
# 7       November          2021     6  Walt Disney Studios Motion Pictures
# 8       November          2021    50                          Screen Gems
# 9          April          2021    34                         Warner Bros.
# 10      November          2021     9    Sony Pictures Entertainment (SPE)
# 11      November          2021    26                   Paramount Pictures
# 12        August          2021    32                   Paramount Pictures
# 13           May          2021    19                         Warner Bros.
# 14      December          2021    51                 20th Century Studios
# 15          July          2021    23                         Warner Bros.
# 16      December          2021    39                         Warner Bros.
# 17        August          2021    10                 20th Century Studios
# 18       October          2021    22             United Artists Releasing
# 19          July          2021    18                         Warner Bros.
# 20          July          2021    11  Walt Disney Studios Motion Pictures
# 21         March          2021    12                         Warner Bros.
# 22          July          2021     4  Walt Disney Studios Motion Pictures
# 23     September          2021    13                         Warner Bros.
# 24         March          2021    54                          Screen Gems
# 25       October          2021    47                 20th Century Studios
# 26         March          2021    24  Walt Disney Studios Motion Pictures
# 27         April          2021    40             United Artists Releasing
# 28     September          2021     7            Metro-Goldwyn-Mayer (MGM)
# 29           May          2021     8                   Paramount Pictures
# 30          June          2021    30                   Universal Pictures
# 31        August          2021    35                          Screen Gems
# 32      February          2021    29                         Warner Bros.
# 33       October          2021    14                   Universal Pictures
# 34          July          2021    28                   Universal Pictures
# 35         March          2021    41                   Universal Pictures
# 36      December          2021    75                 Searchlight Pictures
# 37       October          2021    65                 Searchlight Pictures
# 38           May          2021    48                   Universal Pictures
# 39       October          2021    64                 20th Century Studios
# 40       January          2021    53                 Open Road Films (II)
# 41         April          2021    84                 Open Road Films (II)
# 42       January          2021   119                          Saban Films
# 43         March          2021    31    Sony Pictures Entertainment (SPE)
# 44     September          2021    60                         Warner Bros.
# 45          July          2021    43    Sony Pictures Entertainment (SPE)
#
#    release         gross
# 0   Dec 17  $572,984,769
# 1   Nov 24   $90,628,329
# 2   Dec 22   $74,883,155
# 3    Oct 1  $212,609,036
# 4    Sep 3  $224,543,292
# 5   May 28   $86,103,234
# 6   Sep 10    $2,170,750
# 7    Nov 5  $164,616,321
# 8   Nov 24   $16,923,891
# 9   Apr 23   $37,479,648
# 10  Nov 19  $122,378,960
# 11  Nov 10   $48,947,356
# 12  Aug 20   $40,127,371
# 13   Jun 4   $65,579,078
# 14  Dec 22   $16,258,724
# 15   Aug 6   $55,812,663
# 16  Dec 22   $28,134,634
# 17  Aug 13  $121,626,598
# 18   Oct 1   $56,489,153
# 19  Jul 16   $67,559,184
# 20  Jul 30  $116,987,516
# 21  Mar 31   $99,597,705
# 22   Jul 9  $183,651,655
# 23  Oct 22   $93,404,911
# 24   Apr 2   $15,532,137
# 25  Oct 22   $23,009,270
# 26   Mar 5   $54,723,032
# 27   May 7   $27,466,489
# 28   Oct 8  $160,772,007
# 29  May 28  $160,072,261
# 30   Jul 2   $44,539,245
# 31  Aug 13   $32,712,950
# 32  Feb 26   $46,318,441
# 33  Oct 15   $92,002,155
# 34  Jul 23   $48,242,510
# 35  Mar 26   $27,268,035
# 36  Dec 17    $6,878,302
# 37  Oct 29   $10,619,670
# 38   Jun 4   $17,635,215
# 39  Oct 15   $10,853,945
# 40  Jan 15   $15,566,093
# 41  Apr 30    $4,509,143
# 42  Jan 26    $1,213,800
# 43  Jun 11   $40,501,717
# 44  Sep 10   $13,351,893
# 45  Jul 16   $25,314,753

# %%
movie_total.dtypes
# Out:
# title             object
# popularity       float64
# vote_average     float64
# release_month     object
# release_year       int32
# rank               int64
# studio            object
# release           object
# gross             object
# dtype: object

# %%
# Join the Data sets at the moment it doesnt work :c
# movies_total = movies2_df.join(movies1_df, on= ["title"])

# %%
# Format movies1 columns
# movies1_df

# %% [markdown]
# <h3>Create database connection</h3> *All the following code is a place holder do not run it*

# %%
#pip install psycopg2-binary

# %%
protocol = 'postgresql'
username = '<postgres>'
password = '<postgres>'
host = 'localhost'
port = 5432
database_name = 'MoviesDB2022'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
connection_string = "postgres:postgres@localhost:5432/MoviesDB2021"
engine = create_engine(f'postgresql://{connection_string}')

# %%
movie_total.to_sql(name='movies3', con=engine, if_exists='append', index=True)
# Out:
# 46
